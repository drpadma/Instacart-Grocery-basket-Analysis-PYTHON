# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\harip\Instacart Basket Analysis"

# %%
# Import orders_products_merged
customers = pd.read_csv(os.path.join(path,'02 Data', 'original Data', 'customers.csv'), index_col= False)

# %% [markdown]
# # Data Wrangling

# %%
customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
customers.shape
# Out:
# (206209, 10)

# %% [markdown]
# Renaming Surname to last name to match first name

# %%
customers.rename(columns = {'Surnam': 'Last Name'}, inplace= True)

# %% [markdown]
# Renaming the capital STATE to small State to match other data.

# %%
customers.rename(columns = {'STATE': 'State'} , inplace = True)

# %% [markdown]
# Renaming 'n_dependents' to 'no of dependents'

# %%
customers.rename(columns = {'n_dependants': 'No of dependants'} , inplace = True)

# %%
customers.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    No of dependants fam_status  income
# 0                 3    married  165665
# 1                 0     single   59285
# 2                 2    married   99568
# 3                 0     single   42049
# 4                 1    married   40374

# %% [markdown]
# Not dropping any columns since I find all the data to be useful to my analysis in some parts.

# %%
#Checking for data types
customers.dtypes
# Out:
# user_id              int64
# First Name          object
# Last Name           object
# Gender              object
# State               object
# Age                  int64
# date_joined         object
# No of dependants     int64
# fam_status          object
# income               int64
# dtype: object

# %%
#Checking for the Descriptive statistics
customers.describe()
# Out:
#              user_id            Age  No of dependants         income
# count  206209.000000  206209.000000     206209.000000  206209.000000
# mean   103105.000000      49.501646          1.499823   94632.852548
# std     59527.555167      18.480962          1.118433   42473.786988
# min         1.000000      18.000000          0.000000   25903.000000
# 25%     51553.000000      33.000000          0.000000   59874.000000
# 50%    103105.000000      49.000000          1.000000   93547.000000
# 75%    154657.000000      66.000000          3.000000  124244.000000
# max    206209.000000      81.000000          3.000000  593901.000000

# %% [markdown]
# Checking for missing values

# %%
#Check for the missing values
customers.isnull().sum()
# Out:
# user_id                 0
# First Name          11259
# Last Name               0
# Gender                  0
# State                   0
# Age                     0
# date_joined             0
# No of dependants        0
# fam_status              0
# income                  0
# dtype: int64

# %%
#Changing the null values to Nan as the null values are higher removing it would lead to loss of many data.
df_nan = customers[customers['First Name'].isnull() == True]

# %%
df_nan
# Out:
#         user_id First Name Last Name  Gender         State  Age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         No of dependants fam_status  income
# ...

# %%
#Check for data consistentcy - mixed types
for col in customers.columns.tolist():
  weird = (customers[[col]].applymap(type) != customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customers[weird]) > 0:
    print (col)
# Out:
# First Name

# %%
#Changed 'First Name' to a string
customers['First Name'] = customers['First Name'].astype('str')

# %%
#Checking for the change
print(customers['First Name'].dtypes)
# Out:
# object

# %%
#Checking for null values after changing 'First Name' to 'str'
customers.isnull().sum()
# Out:
# user_id             0
# First Name          0
# Last Name           0
# Gender              0
# State               0
# Age                 0
# date_joined         0
# No of dependants    0
# fam_status          0
# income              0
# dtype: int64

# %%
#Checking for Duplicates
customers_dup = customers[customers.duplicated()]

# %%
customers_dup
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, State, Age, date_joined, No of dependants, fam_status, income]
# Index: []

# %% [markdown]
# No duplicated in the data.

# %% [markdown]
# # Merging the customers data to ords_prods_merge

# %%
#Importing the cleaned orders products updated data set
ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %%
#Checking shape
ords_prods_merge.shape
# Out:
# (32404859, 25)

# %%
#Checking for dtypes
ords_prods_merge.dtypes
# Out:
# product_id                    int64
# product_name                 object
# aisle_id                      int64
# department_id                 int64
# prices                      float64
# order_id                      int64
# user_id                       int64
# order_number                  int64
# orders_day_of_week            int64
# orders_timing_in_day          int64
# days_since_prior_order      float64
# add_to_cart_order             int64
# reordered                     int64
# _merge                     category
#  price_range_loc             object
# price_range_loc              object
# busiest_day                  object
# Busiest_days                 object
# Busiest_period_of_day        object
# max_order                     int64
# loyalty_flag                 object
# average_price               float64
# spending_flag                object
# median_days_prior_order     float64
# frequency_flag               object
# dtype: object

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  orders_timing_in_day  \
# 0   3139998      138            28                   6                    11
# 1   1977647      138            30                   6                    17
# 2    389851      709             2                   0                    21
# 3    652770      764             1                   3                    13
# 4   1813452      764             3                   4                    17
#
# ...

# %% [markdown]
# # Merging the data

# %%
#Merge the data sets with the 'user_id' column
df_combined = ords_prods_merge.merge(customers,on ='user_id')

# %%
df_combined.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2         907        Premium Sliced Bacon       106             12    20.0
# 3         907        Premium Sliced Bacon       106             12    20.0
# 4        1000                    Apricots        18             10    12.9
#
#    order_id  user_id  order_number  orders_day_of_week  orders_timing_in_day  \
# 0   3139998      138            28                   6                    11
# 1   1977647      138            30                   6                    17
# 2   3160996      138             1                   5                    13
# 3   2254091      138            10                   5                    14
# 4    505689      138             9                   6                    12
#
# ...

# %% [markdown]
# # Exporting the merged file

# %%
df_combined.to_pickle(os.path.join(path, '02 Data', 'Prepared Data','customers_orders_merged.pkl'))
